# %%
"""
File Name: Teichler_PracticeLab2_1/22/2026.ipynb
File Author: Benjamin Teichler
Purpose: Lab Work
Date Created: 1/22/2026
"""
# Out:
# '\nFile Name: Teichler_PracticeLab2_1/22/2026.ipynb\nFile Author: Benjamin Teichler\nPurpose: Lab Work\nDate Created: 1/22/2026\n'

# %% [markdown]
# 1. Python Executes Step-by-Step
# Prediction: A,B,C in that order

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %% [markdown]
# 2. Names and Objects
# Prediction: 10

# %%
x = 10
y = x
x = 20
print(y)
# Out:
# 10

# %% [markdown]
# 3. Execution Over Time
# Prediction: Print 6

# %%
x = 5
x = x + 1
print(x)
# Out:
# 6

# %% [markdown]
# 4. Execution Spaces (Functions)
# Prediction: Order: Before, Inside, After

# %%
def add(a,b):
  print("inside")
  return a + b

print("before")
add(2,3)
print("after")
# Out:
# before
# inside
# after

# %% [markdown]
# 5. Function Return
# Prediction: Prints the List

# %%
def make():
  x = [1,2]
  return x

lst = make()
print(lst)
# Out:
# [1, 2]

# %% [markdown]
# 6. Mutation vs Rebinding
# Prediction:
#  #1. 1,2,3
#
#  #2. 9,10

# %%
lst = [1,2]
lst.append(3)
print(lst)
# Out:
# [1, 2, 3]

# %%
lst = [1,2]
lst = [9,10]
print(lst)
# Out:
# [9, 10]

# %% [markdown]
# 7. Function Arguments
# Prediction: 10

# %%
def f(x):
  x = x + 1

a = 10
f(a)
print(a)
# Out:
# 10

# %% [markdown]
# 8. Automatic Iteration
# Prediction: 3 Lines

# %%
for i in [1,2,3]:
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# 9. Iterator Stops
# Prediction: Throws Error

# %%
it = iter([1,2])
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-10269813.py in <cell line: 0>()
#       2 print(next(it))
#       3 print(next(it))
# ----> 4 print(next(it))
#
# StopIteration:

# %% [markdown]
# 10. Generator Does Not Run Immediatley
# Prediction: Nothing will print

# %%
def demo():
  print("A")
  yield 1
  print("B")

x = demo()

# %% [markdown]
# 11. Generator Resumes
# Prediction: Both, A, then, B

# %%
g = demo()
print(next(g))
print(next(g))
# Out:
# A
# 1
# B
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-3130011051.py in <cell line: 0>()
#       1 g = demo()
#       2 print(next(g))
# ----> 3 print(next(g))
#
# StopIteration:

# %% [markdown]
# 12. Closures Preserve Values
# Prediction: Crash

# %%
def outer():
  x = 10
  def inner():
    return x
  return inner

f = outer()
print(f())
# Out:
# 10

# %% [markdown]
# alas I was wrong

# %% [markdown]
# 13. Decorators Change Behavior
# Prediction: 3

# %%
def deco(fn):
  def wrapper():
    print("before")
    fn()
    print("after")
  return wrapper

@deco
def hello():
  print("hello")

hello()
# Out:
# before
# hello
# after

# %% [markdown]
# 14. Attribute Lookup
# Prediciton: 10

# %%
class A:
  x = 10

a = A()
print(a.x)
# Out:
# 10

# %% [markdown]
# 15. Duck Typing
# Prediction: Run

# %%
class MyRange:
  def __iter__(self):
    return self
  def __next__(self):
    raise StopIteration

for x in MyRange():
  print(x)

# %% [markdown]
# I mean it ran, but didnt do anything
